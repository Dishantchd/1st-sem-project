# %% [markdown]
# <a href="https://colab.research.google.com/github/Dishantchd/1st-sem-project/blob/main/DS_practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Practical 1 - Revisiting Pandas and Numpy**

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

url = "https://github.com/USERNAME/REPO/raw/main/dataset.xlsx"
df = pd.read_excel(url)

# %%
df.head(5)
# Out:
#    MATHS  SCIENCE  ENGLISH
# 0   65.0     98.0     91.0
# 1   95.0     88.0     96.0
# 2   70.0     80.0     89.0
# 3   86.0     92.0     74.0
# 4   65.0     78.0     67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   STUDENT ID    40 non-null     object
#  1   STUDENT NAME  34 non-null     object
#  2     GENDER      34 non-null     object
#  3   AGE           34 non-null     float64
#  4   STUDENT MAIL  34 non-null     object
#  5   CONTACT NO.   34 non-null     object
#  6   SGPA          34 non-null     float64
#  7   ATTENDANCE    34 non-null     float64
#  8   MATHS         35 non-null     float64
#  9   ENGLISH       34 non-null     float64
#  10  SCIENCE       34 non-null     float64
#  11  Total_Marks   34 non-null     float64
# dtypes: float64(7), object(5)
# memory usage: 4.0+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = df[['MATHS', 'SCIENCE', 'ENGLISH']]

# %%
df.dropna()
# Out:
#     MATHS  SCIENCE  ENGLISH
# 0    65.0     98.0     91.0
# 1    95.0     88.0     96.0
# 2    70.0     80.0     89.0
# 3    86.0     92.0     74.0
# 4    65.0     78.0     67.0
# 5    98.0     55.0     51.0
# 6    96.0     94.0     82.0
# 7    73.0     79.0     89.0
# 8    52.0     95.0     92.0
# 9    53.0     62.0     99.0
# 10   92.0     57.0     54.0
# 11   86.0     86.0     84.0
# 12   70.0     70.0     61.0
# 13   70.0     83.0     77.0
# 14   98.0     96.0     82.0
# 15   74.0     56.0     80.0
# 16   63.0     84.0     64.0
# 17   74.0     60.0     50.0
# 18   68.0     75.0     55.0
# 19   78.0     70.0     70.0
# 20   66.0     64.0     71.0
# 21   95.0     68.0     65.0
# 22   88.0     57.0     74.0
# 23   87.0     57.0     95.0
# 24   96.0     59.0     54.0
# 25   57.0     80.0     85.0
# 26   81.0     68.0     83.0
# 27   89.0     62.0     53.0
# 28   67.0     87.0     64.0
# 29   76.0     75.0     51.0
# 30   71.0     91.0     68.0
# 31   68.0     89.0     67.0
# ...

# %%
arr = df.to_numpy()

# %%
print("Shape:", arr.shape)
print("Size:", arr.size)
print("Dimensions:", arr.ndim)
# Out:
# Shape: (41, 3)
# Size: 123
# Dimensions: 2

# %%
df_smallarr = df.iloc[0:5]
df_smallarr
# Out:
#    MATHS  SCIENCE  ENGLISH
# 0   65.0     98.0     91.0
# 1   95.0     88.0     96.0
# 2   70.0     80.0     89.0
# 3   86.0     92.0     74.0
# 4   65.0     78.0     67.0

# %%
df_smallarr = df_smallarr.to_numpy()
print(df_smallarr)
# Out:
# [[65. 98. 91.]
#  [95. 88. 96.]
#  [70. 80. 89.]
#  [86. 92. 74.]
#  [65. 78. 67.]]

# %%
print("Shape:", df_smallarr.shape)
print("Size:", df_smallarr.size)
print("Dimensions:", df_smallarr.ndim)
# Out:
# Shape: (5, 3)
# Size: 15
# Dimensions: 2

# %%
df_smallarr.T
# Out:
# array([[65., 95., 70., 86., 65.],
#        [98., 88., 80., 92., 78.],
#        [91., 96., 89., 74., 67.]])

# %%
df_smallarr * 2
# Out:
# array([[130., 196., 182.],
#        [190., 176., 192.],
#        [140., 160., 178.],
#        [172., 184., 148.],
#        [130., 156., 134.]])

# %%
df_smallarr + 5
# Out:
# array([[ 70., 103.,  96.],
#        [100.,  93., 101.],
#        [ 75.,  85.,  94.],
#        [ 91.,  97.,  79.],
#        [ 70.,  83.,  72.]])

# %%
df_smallarr - 10
# Out:
# array([[55., 88., 81.],
#        [85., 78., 86.],
#        [60., 70., 79.],
#        [76., 82., 64.],
#        [55., 68., 57.]])

# %%
np.dot(df_smallarr.T, df_smallarr)
# Out:
# array([[29771., 33312., 31984.],
#        [33312., 38296., 36520.],
#        [31984., 36520., 35383.]])

# %%
smallarr_pseudoinv = np.linalg.pinv(df_smallarr)
print(smallarr_pseudoinv)
# Out:
# [[-2.71729800e-02  1.93639736e-02 -6.39589007e-03  1.59518433e-02
#    3.87689393e-05]
#  [ 2.03062446e-02 -2.80488261e-02 -1.64984831e-02  1.79810986e-02
#    1.46654142e-02]
#  [ 6.17574934e-03  1.41595059e-02  2.53254600e-02 -3.08869649e-02
#   -1.32781537e-02]]
